# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# C:\Users\acer\data-journey-60days\venv\Scripts\python.exe
# 3.13.13 (tags/v3.13.13:01104ce, Apr  7 2026, 19:25:48) [MSC v.1944 64 bit (AMD64)]

# %%
import pandas as pd
df = pd.read_csv("Banking Customer Churn Prediction Dataset.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
display(df.head())
display(df.tail())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  str
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  str
#  5   Gender           10000 non-null  str
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), str(3)
# memory usage: 1.1 MB

# %%
print(df['Tenure'])
# Out:
# 0        2
# 1        1
# 2        8
# 3        1
# 4        2
#         ..
# 9995     5
# 9996    10
# 9997     7
# 9998     3
# 9999     4
# Name: Tenure, Length: 10000, dtype: int64

# %%
df['Tenure'] # Series — одна колонка как список
# Out:
# 0        2
# 1        1
# 2        8
# 3        1
# 4        2
#         ..
# 9995     5
# 9996    10
# 9997     7
# 9998     3
# 9999     4
# Name: Tenure, Length: 10000, dtype: int64

# %%
df[['Tenure']] # Series — одна колонка как Data Frame
# Out:
#       Tenure
# 0          2
# 1          1
# 2          8
# 3          1
# 4          2
# ...      ...
# 9995       5
# 9996      10
# 9997       7
# 9998       3
# 9999       4
#
# [10000 rows x 1 columns]

# %%
df.iloc[24]
# Out:
# RowNumber                 25
# CustomerId          15625047
# Surname                  Yen
# CreditScore              846
# Geography             France
# Gender                Female
# Age                       38
# Tenure                     5
# Balance                  0.0
# NumOfProducts              1
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    187616.16
# Exited                     0
# Name: 24, dtype: object

# %%
df.iloc[499:505]
# Out:
#      RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 499        500    15677020  Selezneva          570    France  Female   58
# 500        501    15727688   Chizuoke          555     Spain    Male   32
# 501        502    15715941      Lueck          692    France    Male   54
# 502        503    15714485    Udinese          774    France    Male   60
# 503        504    15730059    Udobata          638     Spain    Male   44
# 504        505    15715527    Freeman          543     Spain  Female   41
#
#      Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 499       8      0.00              1          0               1
# 500       4      0.00              2          1               1
# 501       5      0.00              2          1               1
# 502       5  85891.55              1          1               0
# 503       9  77637.35              2          1               1
# ...

# %%
df.iloc[503,2]
# Out:
# 'Udobata'

# %%
for index, row in df.iterrows():
    print(row['Surname'], row['Geography'])
# Out:
# Hargrave France
# Hill Spain
# Onio France
# Boni France
# Mitchell Spain
# Chu Spain
# Bartlett France
# Obinna Germany
# He France
# H? France
# Bearce France
# Andrews Spain
# Kay France
# Chin France
# Scott Spain
# Goforth Germany
# Romeo Germany
# Henderson Spain
# Muldrow Spain
# Hao France
# McDonald France
# Dellucci Spain
# Gerasimov Spain
# Mosman France
# Yen France
# Maclean France
# Young Germany
# Nebechi France
# McWilliams Germany
# Lucciano France
# Azikiwe Spain
# Odinakachukwu France
# Sanderson Germany
# Maggard Spain
# Clements Spain
# Lombardo France
# Watson Spain
# Lorenzo Spain
# Armstrong France
# Cameron Germany
# Hsiao Spain
# Clarke France
# Osborne France
# Lavine France
# Bianchi Spain
# Tyler Germany
# Martin Germany
# Okagbue Germany
# Yin Germany
# Buccho Germany
# Chidiebele Germany
# Trevisani Germany
# O'Brien France
# Parkhill Germany
# Yoo Germany
# Phillipps France
# Tsao France
# Endrizzi Germany
# T'ien Spain
# Velazquez France
# ...
