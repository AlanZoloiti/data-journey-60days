# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# C:\Program Files\Python311\python.exe
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]

# %%
import pandas as pd
df = pd.read_csv("Banking Customer Churn Prediction Dataset.csv", index_col='RowNumber')
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
display(df.head())
display(df.tail())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
print(df['Tenure'])
# Out:
# 0        2
# 1        1
# 2        8
# 3        1
# 4        2
#         ..
# 9995     5
# 9996    10
# 9997     7
# 9998     3
# 9999     4
# Name: Tenure, Length: 10000, dtype: int64

# %%
df['Tenure'] # Series — одна колонка как список
# Out:
# 0        2
# 1        1
# 2        8
# 3        1
# 4        2
#         ..
# 9995     5
# 9996    10
# 9997     7
# 9998     3
# 9999     4
# Name: Tenure, Length: 10000, dtype: int64

# %%
df[['Tenure']] # Series — одна колонка как Data Frame
# Out:
#       Tenure
# 0          2
# 1          1
# 2          8
# 3          1
# 4          2
# ...      ...
# 9995       5
# 9996      10
# 9997       7
# 9998       3
# 9999       4
#
# [10000 rows x 1 columns]

# %%
df.iloc[24]
# Out:
# RowNumber                 25
# CustomerId          15625047
# Surname                  Yen
# CreditScore              846
# Geography             France
# Gender                Female
# Age                       38
# Tenure                     5
# Balance                  0.0
# NumOfProducts              1
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    187616.16
# Exited                     0
# Name: 24, dtype: object

# %%
df.iloc[499:505]
# Out:
#      RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 499        500    15677020  Selezneva          570    France  Female   58
# 500        501    15727688   Chizuoke          555     Spain    Male   32
# 501        502    15715941      Lueck          692    France    Male   54
# 502        503    15714485    Udinese          774    France    Male   60
# 503        504    15730059    Udobata          638     Spain    Male   44
# 504        505    15715527    Freeman          543     Spain  Female   41
#
#      Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 499       8      0.00              1          0               1
# 500       4      0.00              2          1               1
# 501       5      0.00              2          1               1
# 502       5  85891.55              1          1               0
# 503       9  77637.35              2          1               1
# ...

# %%
df.iloc[503,2]
# Out:
# 'Udobata'

# %%
df.iloc[[0, 1]]
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %%
#Index(['RowNumber','CustomerId', 'Surname'], dtype='object')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 Index(['RowNumber','CustomerId', 'Surname'], dtype='object')
#
# NameError: name 'Index' is not defined

# %%
df.iloc[[0, 1], [1, 2]]
# Out:
#    CustomerId   Surname
# 0    15634602  Hargrave
# 1    15647311      Hill

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.loc[[1,2], ['Surname', 'CreditScore']]
# Out:
#   Surname  CreditScore
# 1    Hill          608
# 2    Onio          502

# %%
df.loc[[1,2], ['CreditScore', 'Surname']]
# Out:
#    CreditScore Surname
# 1          608    Hill
# 2          502    Onio

# %%
df.set_index('Surname', inplace=True)

# %%
df.sort_index(ascending=False)
# Out:
#          CustomerId  CreditScore Geography  Gender  Age  Tenure    Balance  \
# Surname
# Zuyeva     15689952          724     Spain    Male   41       5       0.00
# Zuyeva     15706810          606   Germany  Female   32       1  106301.85
# Zuyev      15722010          621     Spain    Male   53       9  170491.84
# Zuyev      15583394          659   Germany    Male   39       8  106259.63
# Zuev       15681174          730    France    Male   39       1  116537.60
# ...             ...          ...       ...     ...  ...     ...        ...
# Abbott     15684801          689    France    Male   47       1   93871.95
# Abbott     15680804          850    France    Male   29       6       0.00
# Abbie      15737792          818    France  Female   31       1  186796.37
# Abazu      15576156          710     Spain  Female   28       6       0.00
# Abazu      15708791          584     Spain    Male   32       9   85534.83
#
# ...

# %%
df
# Out:
#            CustomerId  CreditScore Geography  Gender  Age  Tenure    Balance  \
# Surname
# Hargrave     15634602          619    France  Female   42       2       0.00
# Hill         15647311          608     Spain  Female   41       1   83807.86
# Onio         15619304          502    France  Female   42       8  159660.80
# Boni         15701354          699    France  Female   39       1       0.00
# Mitchell     15737888          850     Spain  Female   43       2  125510.82
# ...               ...          ...       ...     ...  ...     ...        ...
# Obijiaku     15606229          771    France    Male   39       5       0.00
# Johnstone    15569892          516    France    Male   35      10   57369.61
# Liu          15584532          709    France  Female   36       7       0.00
# Sabbatini    15682355          772   Germany    Male   42       3   75075.31
# Walker       15628319          792    France  Female   28       4  130142.79
#
# ...

# %%
df.loc['Liu', 'Gender']
# Out:
# Surname
# Liu      Male
# Liu      Male
# Liu      Male
# Liu    Female
# Liu      Male
# Liu      Male
# Liu      Male
# Liu    Female
# Liu      Male
# Liu      Male
# Liu    Female
# Liu    Female
# Name: Gender, dtype: object

# %%
df.iloc[0]
# Out:
# RowNumber                  1
# CustomerId          15634602
# CreditScore              619
# Geography             France
# Gender                Female
# Age                       42
# Tenure                     2
# Balance                  0.0
# NumOfProducts              1
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    101348.88
# Exited                     1
# Name: Hargrave, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#       level_0  index    Surname  RowNumber  CustomerId  CreditScore Geography  \
# 0           0      0   Hargrave          1    15634602          619    France
# 1           1      1       Hill          2    15647311          608     Spain
# 2           2      2       Onio          3    15619304          502    France
# 3           3      3       Boni          4    15701354          699    France
# 4           4      4   Mitchell          5    15737888          850     Spain
# ...       ...    ...        ...        ...         ...          ...       ...
# 9995     9995   9995   Obijiaku       9996    15606229          771    France
# 9996     9996   9996  Johnstone       9997    15569892          516    France
# 9997     9997   9997        Liu       9998    15584532          709    France
# 9998     9998   9998  Sabbatini       9999    15682355          772   Germany
# 9999     9999   9999     Walker      10000    15628319          792    France
#
# ...
